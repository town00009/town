# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pima(For Random Forest Program).csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = df.drop("Outcome",axis=1)
y = df["Outcome"]
x
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 102)

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
Y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy-DecisionTree :",accuracy_score(y_test,Y_pred))
# Out:
# Accuracy-DecisionTree : 0.7272727272727273

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
print("For decision tree")
print(classification_report(y_test, Y_pred))
# Out:
# For decision tree
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79       108
#            1       0.53      0.70      0.60        46
#
#     accuracy                           0.73       154
#    macro avg       0.69      0.72      0.70       154
# weighted avg       0.76      0.73      0.74       154

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(clf,fontsize=8)
# Out:
# [Text(0.47547079694323147, 0.9615384615384616, 'X[1] <= 127.5\ngini = 0.462\nsamples = 614\nvalue = [392, 222]'),
#  Text(0.21158569868995633, 0.8846153846153846, 'X[7] <= 28.5\ngini = 0.326\nsamples = 390\nvalue = [310, 80]'),
#  Text(0.04694323144104803, 0.8076923076923077, 'X[5] <= 30.95\ngini = 0.154\nsamples = 214\nvalue = [196, 18]'),
#  Text(0.017467248908296942, 0.7307692307692307, 'X[6] <= 0.672\ngini = 0.016\nsamples = 127\nvalue = [126, 1]'),
#  Text(0.008733624454148471, 0.6538461538461539, 'gini = 0.0\nsamples = 109\nvalue = [109, 0]'),
#  Text(0.026200873362445413, 0.6538461538461539, 'X[6] <= 0.686\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.017467248908296942, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.034934497816593885, 0.5769230769230769, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.07641921397379912, 0.7307692307692307, 'X[2] <= 37.0\ngini = 0.314\nsamples = 87\nvalue = [70, 17]'),
#  Text(0.06768558951965066, 0.6538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0851528384279476, 0.6538461538461539, 'X[1] <= 101.5\ngini = 0.291\nsamples = 85\nvalue = [70, 15]'),
#  Text(0.05240174672489083, 0.5769230769230769, 'X[5] <= 31.1\ngini = 0.133\nsamples = 42\nvalue = [39, 3]'),
#  Text(0.043668122270742356, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0611353711790393, 0.5, 'X[6] <= 1.272\ngini = 0.093\nsamples = 41\nvalue = [39, 2]'),
#  Text(0.05240174672489083, 0.4230769230769231, 'X[6] <= 0.772\ngini = 0.049\nsamples = 40\nvalue = [39, 1]'),
#  Text(0.043668122270742356, 0.34615384615384615, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.0611353711790393, 0.34615384615384615, 'X[6] <= 0.898\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.05240174672489083, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06986899563318777, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06986899563318777, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11790393013100436, 0.5769230769230769, 'X[5] <= 33.7\ngini = 0.402\nsamples = 43\nvalue = [31, 12]'),
#  Text(0.09606986899563319, 0.5, 'X[0] <= 1.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.08733624454148471, 0.4230769230769231, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.10480349344978165, 0.4230769230769231, 'X[5] <= 32.4\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.09606986899563319, 0.34615384615384615, 'X[7] <= 24.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08733624454148471, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10480349344978165, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11353711790393013, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13973799126637554, 0.5, 'X[0] <= 1.5\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(0.13100436681222707, 0.4230769230769231, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.14847161572052403, 0.4230769230769231, 'X[4] <= 134.5\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(0.13973799126637554, 0.34615384615384615, 'X[5] <= 35.75\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.1222707423580786, 0.2692307692307692, 'X[3] <= 42.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.11353711790393013, 0.19230769230769232, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.13100436681222707, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1572052401746725, 0.2692307692307692, 'X[6] <= 0.799\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14847161572052403, 0.19230769230769232, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.16593886462882096, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1572052401746725, 0.34615384615384615, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.37622816593886466, 0.8076923076923077, 'X[4] <= 142.5\ngini = 0.456\nsamples = 176\nvalue = [114, 62]'),
#  Text(0.26774017467248906, 0.7307692307692307, 'X[1] <= 100.5\ngini = 0.416\nsamples = 149\nvalue = [105, 44]'),
#  Text(0.22270742358078602, 0.6538461538461539, 'X[1] <= 22.0\ngini = 0.234\nsamples = 59\nvalue = [51, 8]'),
#  Text(0.21397379912663755, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.
 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8624454148471615, 0.6538461538461539, 'X[4] <= 297.5\ngini = 0.385\nsamples = 50\nvalue = [13, 37]'),
#  Text(0.8384279475982532, 0.5769230769230769, 'X[7] <= 30.0\ngini = 0.303\nsamples = 43\nvalue = [8, 35]'),
#  Text(0.8165938864628821, 0.5, 'X[2] <= 72.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.7991266375545851, 0.4230769230769231, 'X[3] <= 38.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.7903930131004366, 0.34615384615384615, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8078602620087336, 0.34615384615384615, 'X[3] <= 43.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7991266375545851, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8165938864628821, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.834061135371179, 0.4230769230769231, 'X[2] <= 85.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.8253275109170306, 0.34615384615384615, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8427947598253275, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8602620087336245, 0.5, 'X[5] <= 40.05\ngini = 0.137\nsamples = 27\nvalue = [2, 25]'),
#  Text(0.851528384279476, 0.4230769230769231, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.868995633187773, 0.4230769230769231, 'X[2] <= 81.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8602620087336245, 0.34615384615384615, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8777292576419214, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8864628820960698, 0.5769230769230769, 'X[7] <= 44.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.8777292576419214, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8951965065502183, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9650655021834061, 0.7307692307692307, 'X[4] <= 629.5\ngini = 0.214\nsamples = 74\nvalue = [9, 65]'),
#  Text(0.9475982532751092, 0.6538461538461539, 'X[3] <= 32.5\ngini = 0.178\nsamples = 71\nvalue = [7, 64]'),
#  Text(0.9388646288209607, 0.5769230769230769, 'X[6] <= 1.157\ngini = 0.263\nsamples = 45\nvalue = [7, 38]'),
#  Text(0.9213973799126638, 0.5, 'X[5] <= 35.3\ngini = 0.21\nsamples = 42\nvalue = [5, 37]'),
#  Text(0.9126637554585153, 0.4230769230769231, 'X[6] <= 0.298\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.8951965065502183, 0.34615384615384615, 'X[6] <= 0.27\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.8864628820960698, 0.2692307692307692, 'X[5] <= 33.9\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8777292576419214, 0.19230769230769232, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8951965065502183, 0.19230769230769232, 'X[7] <= 31.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8864628820960698, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9039301310043668, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9039301310043668, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9301310043668122, 0.34615384615384615, 'X[7] <= 45.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.9213973799126638, 0.2692307692307692, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9388646288209607, 0.2692307692307692, 'X[5] <= 33.45\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9301310043668122, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9475982532751092, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9301310043668122, 0.4230769230769231, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.9563318777292577, 0.5, 'X[1] <= 168.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9475982532751092, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9650655021834061, 0.4230769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9563318777292577, 0.5769230769230769, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.982532751091703, 0.6538461538461539, 'X[6] <= 0.412\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9737991266375546, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9912663755458515, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(x_train,y_train)
y_predict = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy-Random Forest :",accuracy_score(y_test,y_predict))
# Out:
# Accuracy-Random Forest : 0.7727272727272727

# %%
print("For random forest")
print(classification_report(y_test,y_predict))
# Out:
# For random forest
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       108
#            1       0.63      0.57      0.60        46
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.71      0.72       154
# weighted avg       0.77      0.77      0.77       154

# %%
feature = pd.DataFrame(
{
    "feature":list(x.columns),
    "importance":clf.feature_importances_
}).sort_values("importance",ascending=False)
feature
# Out:
#                     feature  importance
# 1                   Glucose    0.253381
# 5                       BMI    0.165198
# 7                       Age    0.140695
# 6  DiabetesPedigreeFunction    0.124643
# 0               Pregnancies    0.088370
# 2             BloodPressure    0.082025
# 3             SkinThickness    0.073556
# 4                   Insulin    0.072132

# %%
import seaborn as sns
sns.barplot(x=feature.feature,y=feature.importance)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Glucose'),
#   Text(1, 0, 'BMI'),
#   Text(2, 0, 'Age'),
#   Text(3, 0, 'DiabetesPedigreeFunction'),
#   Text(4, 0, 'Pregnancies'),
#   Text(5, 0, 'BloodPressure'),
#   Text(6, 0, 'SkinThickness'),
#   Text(7, 0, 'Insulin')])
